# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('.')))
import torch
import pandas as pd
from modules.preprocessing import load_config, load_and_split, OUTPUT_NAMES, INPUT_COLS
from modules.training import run_iterative_training, plot_results, save_model

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')

TARGET = 'Dy'
# Out:
# Device: cuda

# %%
YAML_PATH = Path('hyperparameters.yaml')
hp, DS, DNN_DEFAULTS, OUTS, TRAIN_SPLIT, R2_THRESHOLD, INCREMENT, MAX_ITER = load_config(YAML_PATH)
print(f'Target: {TARGET}  |  R2_threshold={R2_THRESHOLD}  increment={INCREMENT}  max_iter={MAX_ITER}')
# Out:
# Target: Dy  |  R2_threshold=0.9  increment=2000  max_iter=40

# %%
DATA_PATH = Path('../1. Dataset/DNN_dataset_cleaned.csv')
X_train_all, X_test, Y_train_all, Y_test, scaler = load_and_split(
    DATA_PATH, INPUT_COLS, OUTPUT_NAMES, TRAIN_SPLIT
)
print(f'X_train_all: {X_train_all.shape}  |  X_test: {X_test.shape}')
# Out:
# Loaded 110,649 rows x 42 columns
# Random split  --  train: 88,519  |  test: 22,130
# X_train_all: (88519, 23)  |  X_test: (22130, 23)

# %%
result = run_iterative_training(
    TARGET, X_train_all, Y_train_all, X_test, Y_test,
    INCREMENT, MAX_ITER, R2_THRESHOLD,
    OUTPUT_NAMES, OUTS, DNN_DEFAULTS, device
)
# Out:
# ============================================================
#   Training: Dy
# ============================================================
#
#   -- iter   1 | n=  2,000 --
#     epoch  500 | train MSE=0.018237 | test MSE=0.010928 | train R2=0.1331 | test R2=0.0890 | cumulative time=1m 16s
#     epoch 1000 | train MSE=0.003503 | test MSE=0.004854 | train R2=0.8454 | test R2=0.5954 | cumulative time=2m 32s
#     epoch 1500 | train MSE=0.002504 | test MSE=0.003897 | train R2=0.9200 | test R2=0.6752 | cumulative time=3m 49s
#     Early stopping at epoch 1937.
#   iter   1 DONE | n=  2,000 | train R2=0.9256 | test R2=0.6907 | iter time=299.2s  (epochs total=297.8s)
#   *** New best model saved (test R2=0.6907)
#
#   -- iter   2 | n=  4,000 --
#     epoch  500 | train MSE=0.004505 | test MSE=0.004441 | train R2=0.7577 | test R2=0.6298 | cumulative time=1m 46s
#     epoch 1000 | train MSE=0.002800 | test MSE=0.003776 | train R2=0.8495 | test R2=0.6852 | cumulative time=3m 34s
#     Early stopping at epoch 1249.
#   iter   2 DONE | n=  4,000 | train R2=0.8820 | test R2=0.7279 | iter time=267.5s  (epochs total=267.3s)
#   *** New best model saved (test R2=0.7279)
#
#   -- iter   3 | n=  6,000 --
#     epoch  500 | train MSE=0.003389 | test MSE=0.003333 | train R2=0.8024 | test R2=0.7222 | cumulative time=2m 17s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result = run_iterative_training(
#       2     TARGET, X_train_all, Y_train_all, X_test, Y_test,
#       3     INCREMENT, MAX_ITER, R2_THRESHOLD,
#       4     OUTPUT_NAMES, OUTS, DNN_DEFAULTS, device
#       5 )
#
# File ~/DL_paper_repr/Prof.-Gardoni-Paper-Reproduction-Work/3. Codes/modules/training.py:208, in run_iterative_training(output_name, X_train_all, Y_train_all, X_test, Y_test, increment, max_iter, r2_threshold, output_names, outs_cfg, defaults_cfg, device)
#     201 iter_start = time.perf_counter()
#     202 print(f"\n  -- iter {iteration:3d} | n={n_samples:7,} --")
#     204 (model, tr_loss, te_loss,
#     205  tr_r2, te_r2,
#     206  y_tr_true, y_te_true,
#     207  pred_tr, pred_te,
# --> 208  epoch_times) = train_one_model(
#     209     output_name, X_tr, Y_tr, X_test, Y_test,
#     210     output_names, outs_cfg, defaults_cfg, device
#     211 )
#     213 iter_elapsed = time.perf_counter() - iter_start
#     214 epoch_total  = sum(epoch_times)
#
# File ~/DL_paper_repr/Prof.-Gardoni-Paper-Reproduction-Work/3. Codes/modules/training.py:97, in train_one_model(output_name, X_tr, Y_tr, X_te, Y_te, output_names, outs_cfg, defaults_cfg, device)
#      95 optimizer.zero_grad()
#      96 loss = criterion(model(xb), yb)
# ---> 97 loss.backward()
#      98 optimizer.step()
#      99 running += loss.item() * len(xb)
#
# File /opt/conda/lib/python3.13/site-packages/torch/_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)    628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File /opt/conda/lib/python3.13/site-packages/torch/autograd/__init__.py:364, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     359     retain_graph = create_graph
#     361 # The reason we repeat the same comment below is that
#     362 # some Python versions print out the first line of a multi-line function
#     363 # calls in the traceback and some print out the last line
# --> 364 _engine_run_backward(
#     365     tensors,
#     366     grad_tensors_,
#     367     retain_graph,
#     368     create_graph,
#     369     inputs_tuple,
#     370     allow_unreachable=True,
#     371     accumulate_grad=True,
#     372 )
#
# File /opt/conda/lib/python3.13/site-packages/torch/autograd/graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
print(f"\nBest model for {TARGET}")
print(f"  Dataset size : {result['final_n']:,}")
print(f"  Train R2     : {result['train_r2']:.4f}")
print(f"  Test R2      : {result['test_r2']:.4f}")
print(f"  R2 >= 0.90   : {'YES' if result['test_r2'] >= R2_THRESHOLD else 'NO'}")

# %%
plot_results(TARGET, result, R2_THRESHOLD, save_path=f'results_{TARGET}.png')

# %%
save_model(result['model'], TARGET, Path('saved_models'))
